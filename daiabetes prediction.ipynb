# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('data.csv')

# %%
data
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# ..        ...           ...           ...        ...      ...   ...
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age    skin  diabetes
# 0        0.627   50  1.3790      True
# 1        0.351   31  1.1426     False
# ...

# %%
data.describe()
# Out:
#          num_preg  glucose_conc  diastolic_bp   thickness     insulin  \
# count  768.000000    768.000000    768.000000  768.000000  768.000000
# mean     3.845052    120.894531     69.105469   20.536458   79.799479
# std      3.369578     31.972618     19.355807   15.952218  115.244002
# min      0.000000      0.000000      0.000000    0.000000    0.000000
# 25%      1.000000     99.000000     62.000000    0.000000    0.000000
# 50%      3.000000    117.000000     72.000000   23.000000   30.500000
# 75%      6.000000    140.250000     80.000000   32.000000  127.250000
# max     17.000000    199.000000    122.000000   99.000000  846.000000
#
#               bmi   diab_pred         age        skin
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.809136
# std      7.884160    0.331329   11.760232    0.628517
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
data.shape
# Out:
# (768, 10)

# %%
data.isnull()
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin    bmi  \
# 0       False         False         False      False    False  False
# 1       False         False         False      False    False  False
# 2       False         False         False      False    False  False
# 3       False         False         False      False    False  False
# 4       False         False         False      False    False  False
# ..        ...           ...           ...        ...      ...    ...
# 763     False         False         False      False    False  False
# 764     False         False         False      False    False  False
# 765     False         False         False      False    False  False
# 766     False         False         False      False    False  False
# 767     False         False         False      False    False  False
#
#      diab_pred    age   skin  diabetes
# 0        False  False  False     False
# 1        False  False  False     False
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
sns.heatmap(data.isnull())

# %%
corr_mat = data.corr()
corr_mat
# Out:
#               num_preg  glucose_conc  diastolic_bp  thickness   insulin  \
# num_preg      1.000000      0.129459      0.141282  -0.081672 -0.073535
# glucose_conc  0.129459      1.000000      0.152590   0.057328  0.331357
# diastolic_bp  0.141282      0.152590      1.000000   0.207371  0.088933
# thickness    -0.081672      0.057328      0.207371   1.000000  0.436783
# insulin      -0.073535      0.331357      0.088933   0.436783  1.000000
# bmi           0.017683      0.221071      0.281805   0.392573  0.197859
# diab_pred    -0.033523      0.137337      0.041265   0.183928  0.185071
# age           0.544341      0.263514      0.239528  -0.113970 -0.042163
# skin         -0.081672      0.057328      0.207371   1.000000  0.436783
# diabetes      0.221898      0.466581      0.065068   0.074752  0.130548
#
#                    bmi  diab_pred       age      skin  diabetes
# num_preg      0.017683  -0.033523  0.544341 -0.081672  0.221898
# ...

# %%
data['diabetes'].replace('True',1,inplace=True)

# %%
data.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin  diabetes
# 0   50  1.3790      True
# 1   31  1.1426     False
# 2   32  0.0000      True
# 3   21  0.9062     False
# 4   33  1.3790      True

# %%
corrmat= data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(16,6))
sns.heatmap(data[top_corr_features].corr(),annot=True)

# %%
#now converting True False into 1 and 0 using mapping a dictionary
diabetes_map = {True:1,False:0}
data['diabetes']= data['diabetes'].map(diabetes_map)

# %%
data.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin  diabetes
# 0   50  1.3790         1
# 1   31  1.1426         0
# 2   32  0.0000         1
# 3   21  0.9062         0
# 4   33  1.3790         1

# %%
data['diabetes'].value_counts()
#to check whether a data is balanced or not
# Out:
# 0    500
# 1    268
# Name: diabetes, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
Y= data['diabetes']

# %%
X=data.drop('diabetes',axis=1)

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: diabetes, Length: 768, dtype: int64

# %%
X
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# ..        ...           ...           ...        ...      ...   ...
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age    skin
# 0        0.627   50  1.3790
# 1        0.351   31  1.1426
# 2        0.672   32  0.0000
# 3        0.167   21  0.9062
# ...

# %%
#Since many values in our data set are 0 , which means we have some missing values,
#counting the missiong values
print('Missing values in glucose_conc:',len(data.loc[data['glucose_conc']==0]))
print('Missing values in diastolic_bp:',len(data.loc[data['diastolic_bp']==0]))
print('Missing values in thickness:',len(data.loc[data['thickness']==0]))
print('Missing values in insulin:',len(data.loc[data['insulin']==0]))
print('Missing values in bmi:',len(data.loc[data['bmi']==0]))
print('Missing values in diab_pred:',len(data.loc[data['diab_pred']==0]))
print('Missing values in age:',len(data.loc[data['age']==0]))
print('Missing values in skin:',len(data.loc[data['skin']==0]))
# Out:
# Missing values in glucose_conc: 5
# Missing values in diastolic_bp: 35
# Missing values in thickness: 227
# Missing values in insulin: 374
# Missing values in bmi: 11
# Missing values in diab_pred: 0
# Missing values in age: 0
# Missing values in skin: 227

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
from sklearn.impute import SimpleImputer
fill_values = SimpleImputer(missing_values=0,strategy='mean')
X_train = fill_values.fit_transform(X_train)
X_test = fill_values.fit_transform(X_test)
#not working

# %%
X.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin
# 0   50  1.3790
# 1   31  1.1426
# 2   32  0.0000
# 3   21  0.9062
# 4   33  1.3790

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model1= RandomForestClassifier(random_state=0)
model1.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
predict = model1.predict(X_test)
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(Y_test,predict))
#accuracy is 76 percentage
# Out:
# 0.7619047619047619
